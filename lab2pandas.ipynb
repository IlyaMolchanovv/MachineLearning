# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyaMolchanovv/MachineLearning/blob/main/lab2pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Загрузить данные (read_csv())

# %%
data = pd.read_csv("/content/math_students.csv")

# %% [markdown]
# Вывести первые и последние 10 строк таблицы (head(), tail())

# %%
data.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
data.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %% [markdown]
# Вывести число объектов и их характеристик

# %%
len(data)
# Out:
# 395

# %%
len(data.columns)
# Out:
# 33

# %% [markdown]
# Вывести названий всех колонок

# %%
list(data.columns)
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %% [markdown]
# Есть ли в данных пропуски

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# Вывести статистику по значениям признаков

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Вывести более подробное описание значений признаков (количество непустых
# значений, типов столбцов и объема занимаемой памяти)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# Какие значения принимает признак одни из признаков (например, guardian)? (какие
# именно значения, сколько уникальных, сколько значений каждого типа)

# %%
data['guardian'].value_counts()
# Out:
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64

# %% [markdown]
# Вывести только тех студентов, у которых опекуном является мать, и которая
# работает учителем или на дому:

# %%
data[(data['guardian'] == 'mother') & ((data['Mjob'] == 'teacher') | (data['Mjob'] == 'at_home'))]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 13      GP   M   15       U     GT3       T     4     3  teacher     other
# 20      GP   M   15       U     GT3       T     4     3  teacher     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 377     MS   F   18       R     LE3       T     4     4  teacher  services
# 379     MS   F   17       R     GT3       T     3     1  at_home     other
# 385     MS   F   18       R     GT3       T     2     2  at_home     other
# 386     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1  teacher  services
#
# ...

# %% [markdown]
# Создать признак "alc", который будет отражать общее употребление алкоголя в
# течение недели

# %%
data['alc'] = data['Dalc'] + data['Walc']
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 alc
# 0        3     4     1     1       3        6   5   6   6   2
# 1        3     3     1     1       3        4   5   5   6   2
# 2        3     2     2     3       3       10   7   8  10   5
# 3        2     2     1     1       5        2  15  14  15   2
# 4        3     2     1     2       5        4   6  10  10   3
#
# [5 rows x 34 columns]

# %% [markdown]
# Вывести новый размер, новые колонки

# %%
data.shape
# Out:
# (395, 34)

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'alc'],
#       dtype='object')

# %% [markdown]
# Какая причина выбора школы была самой частой? В качестве ответа приведите
# соответствующее значение признака.

# %%
data['reason'].value_counts().idxmax()
# Out:
# 'course'

# %% [markdown]
# Найдите количество студентов, у родителей которых нет никакого образования.
# Вывести информацию об этих студентах.

# %%
par_no_edu = data[(data['Medu'] == 0) & (data['Fedu'] == 0)]
print(len(par_no_edu))
par_no_edu
# Out:
# 0
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3, alc]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# Найдите минимальный возраст учащегося школы Mousinho da Silveira. Вывести
# информацию об этих студентах.

# %%
min_age_mousinho = data[data['school'] == 'MS']['age'].min()
students_min_age_mousinho = data[(data['school'] == 'MS') & (data['age'] == min_age_mousinho)]
print("Минимальный возраст:", min_age_mousinho)
students_min_age_mousinho
# Out:
# Минимальный возраст: 17
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 351     MS   M   17       U     GT3       T     3     3    health     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 356     MS   F   17       R     GT3       T     4     4   teacher  services
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 363     MS   F   17       U     LE3       T     4     4   at_home   at_home
# 364     MS   F   17       R     GT3       T     1     2     other  services
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 372     MS   F   17       U     GT3       T     2     2     other   at_home
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# 382     MS   M   17       U     GT3       T     2     3     other  services
# ...

# %% [markdown]
# Найдите количество студентов, имеющих нечетное число пропусков. Вывести
# информацию об этих студентах

# %%
odd_absences = data[data['absences'] % 2 != 0]
print("Количество студентов:", len(odd_absences))
odd_absences
# Out:
# Количество студентов: 41
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 37      GP   M   16       R     GT3       A     4     4     other   teacher
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 206     GP   F   16       U     GT3       A     3     1  services     other
# 211     GP   M   17       U     LE3       T     4     4  services     other
# 213     GP   M   18       U     GT3       T     2     2  services     other
# 217     GP   M   18       U     LE3       T     3     3  services    health
# 218     GP   F   17       U     GT3       T     2     3   at_home     other
# 260     GP   F   18       U     GT3       T     4     3  services     other
# 262     GP   M   18       R     GT3       T     3     2     other     other
# 265     GP   M   18       R     LE3       A     3     4     other     other
# 270     GP   F   19       U     GT3       T     3     3     other  services
# ...

# %% [markdown]
# Найдите разность между средними итоговыми оценками студентов, состоящих и не
# состоящих в романтических отношениях. В качестве ответа приведите число, округленное
# до двух значащих цифр после запятой. Вывести информацию об этих студентах.

# %%
mean_grade_in_relationship = data[data['romantic'] == 'yes']['G3'].mean()
mean_grade_not_in_relationship = data[data['romantic'] == 'no']['G3'].mean()

difference = mean_grade_in_relationship - mean_grade_not_in_relationship
rounded_difference = round(difference, 2)

print("Разность между средними оценками студентов, состоящих и не состоящих в романтических отношениях:", rounded_difference)
# Out:
# Разность между средними оценками студентов, состоящих и не состоящих в романтических отношениях: -1.26

# %% [markdown]
# Подсчитать количество студентов каждого пола

# %%
gender_counts = data['sex'].value_counts()
print(f"Количество студентов каждого пола:\n{gender_counts}")
# Out:
# Количество студентов каждого пола:
# F    208
# M    187
# Name: sex, dtype: int64

# %% [markdown]
# Подсчитать количество студентов, чья опекуном является отец и который работает
# врачом(полицейским). Вывести информацию об этих студентах

# %%
subset = data[(data['guardian'] == 'father') & ((data['Fjob'] == 'health') | (data['Fjob'] == 'services'))]
print("Количество студентов:")
print(len(subset))
print("Информация о студентах:")
subset
# Out:
# Количество студентов:
# 42
# Информация о студентах:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 12      GP   M   15       U     LE3       T     4     4    health  services
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 43      GP   M   15       U     GT3       T     2     2  services  services
# 52      GP   M   15       U     LE3       A     4     2    health    health
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 62      GP   F   16       U     LE3       T     1     2     other  services
# 64      GP   F   15       U     LE3       T     4     3  services  services
# 80      GP   M   15       U     GT3       T     2     3     other  services
# 85      GP   F   15       U     GT3       T     4     4  services  services
# 105     GP   F   15       U     GT3       A     3     3     other    health
# 117     GP   M   16       U     GT3       T     3     3     other  services
# ...

# %% [markdown]
# Подсчитать количество студентов, выбравших школу из-за репутации. Вывести
# информацию об этих студентах

# %%
reputation_students = data[data['reason'] == 'reputation']
print("Количество студентов, выбравших школу из-за репутации:")
print(len(reputation_students))
print("Информация о студентах:")
reputation_students
# Out:
# Количество студентов, выбравших школу из-за репутации:
# 105
# Информация о студентах:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# ...

# %% [markdown]
# Найти максимальное количество пропусков у студента. Вывести информацию об
# этих студентах

# %%
max_absences = data['absences'].max()
students_with_max_absences = data[data['absences'] == max_absences]
print("Максимальное количество пропусков:", max_absences)
print("Информация о студентах:")
students_with_max_absences
# Out:
# Максимальное количество пропусков: 75
# Информация о студентах:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  ...  \
# 276     GP   F   18       R     GT3       A     3     2  other  services  ...
#
#     freetime goout  Dalc  Walc  health absences  G1 G2 G3 alc
# 276        1     1     1     1       5       75  10  9  9   2
#
# [1 rows x 34 columns]

# %% [markdown]
# Подсчитать количество студентов, чьи родители имеют высшее образование.
# Вывести информацию об этих студентаx

# %%
parents_high_education = data[(data['Medu'] == 4) & (data['Fedu'] == 4)]
print("Количество студентов:")
print(len(parents_high_education))
print("Информация о студентах:")
parents_high_education
# Out:
# Количество студентов:
# 70
# Информация о студентах:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 7       GP   F   17       U     GT3       A     4     4    other   teacher
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 12      GP   M   15       U     LE3       T     4     4   health  services
# 15      GP   F   16       U     GT3       T     4     4   health     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 369     MS   F   18       R     GT3       T     4     4    other   teacher
# 374     MS   F   18       R     LE3       T     4     4    other     other
# 377     MS   F   18       R     LE3       T     4     4  teacher  services
# 380     MS   M   18       U     GT3       T     4     4  teacher   teacher
# 386     MS   F   18       R     GT3       T     4     4  teacher   at_home
#
# ...

# %% [markdown]
# Найти максимальный возраст учащегося, имеющего более 5 пропусков. Вывести его.
# Вывести информацию об этих студентах.

# %%
max_age_with_high_absences = data[data['absences'] > 5]['age'].max()
students_with_max_age_and_high_absences = data[(data['absences'] > 5) & (data['age'] == max_age_with_high_absences)]
print("Максимальный возраст учащегося с более чем 5 пропусками:", max_age_with_high_absences)
print("Информация о студентах:")
students_with_max_age_and_high_absences
# Out:
# Максимальный возраст учащегося с более чем 5 пропусками: 22
# Информация о студентах:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T     3     1  services  services
#
#      ... freetime goout  Dalc  Walc  health absences G1 G2 G3 alc
# 247  ...        4     5     5     5       1       16  6  8  8  10
#
# [1 rows x 34 columns]

# %% [markdown]
# Найдите разность между средними итоговыми оценками студентов, у которых есть
# домашний интернет и у которых его нет. В качестве ответа приведите число, округленное
# до двух значащих цифр после запятой. Вывести информацию об этих студентах

# %%
mean_grade_with_internet = data[data['internet'] == 'yes']['G3'].mean()
mean_grade_without_internet = data[data['internet'] == 'no']['G3'].mean()

difference = mean_grade_with_internet - mean_grade_without_internet
rounded_difference = round(difference, 2)

print("Разность между средними оценками студентов с домашним интернетом и без него:", rounded_difference)
# Out:
# Разность между средними оценками студентов с домашним интернетом и без него: 1.21
